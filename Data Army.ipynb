# %%
#1. Importing of relevant libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Netflix_data.csv') # Loading the data

data.head(5)  # Showing first 5 rows of the data
# Out:
#                                            Title        Date
# 0                               Almost Christmas  24/12/2024
# 1                              Our Little Secret  18/12/2024
# 2                 Twas the Text Before Christmas  18/12/2024
# 3  My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4      My Demon: Limited Series: The End of Fate  10/12/2024

# %%
data
# Out:
#                                              Title        Date
# 0                                 Almost Christmas  24/12/2024
# 1                                Our Little Secret  18/12/2024
# 2                   Twas the Text Before Christmas  18/12/2024
# 3    My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4        My Demon: Limited Series: The End of Fate  10/12/2024
# ..                                             ...         ...
# 110        All of Us Are Dead: Season 1: Episode 2  08/03/2024
# 111        All of Us Are Dead: Season 1: Episode 1  08/03/2024
# 112               Zom 100: Bucket List of the Dead  08/03/2024
# 113           Happiness: Limited Series: Episode 1  08/03/2024
# 114                Avatar The Last Airbender: Aang  07/03/2024
#
# [115 rows x 2 columns]

# %%
#(3) checking top 5 rows of the data using .head() function

data.head()
# Out:
#                                            Title        Date
# 0                               Almost Christmas  24/12/2024
# 1                              Our Little Secret  18/12/2024
# 2                 Twas the Text Before Christmas  18/12/2024
# 3  My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4      My Demon: Limited Series: The End of Fate  10/12/2024

# %%
#(4) Number of rows and columns in the dataset

data.shape
# Out:
# (115, 2)

# %%
#(4) Number of rows in the dataset

data.shape[0]
# Out:
# 115

# %%
#(4) Number of columns in the dataset

data.shape[1]
# Out:
# 2

# %%
# Checking for null values and suming them in the dataset

data.isnull().sum()
# Out:
# Title    0
# Date     0
# dtype: int64

# %%
#(5) Description of the dataset

data.describe()
# Out:
#                    Title        Date
# count                115         115
# unique               115          48
# top     Almost Christmas  21/07/2024
# freq                   1          13

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   115 non-null    object
#  1   Date    115 non-null    object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
#Checking duplicate

data.duplicated().sum()
# Out:
# 0

# %%
data['Title'] = data['Name'].apply(lambda title : tilte)  # Extracting title from names
print(df['Title'].head())
